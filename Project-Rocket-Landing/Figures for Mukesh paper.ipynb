# %%
import matplotlib.pyplot as plt

# Define the points
x = [0, 2/3, 1]
y = [-2, 2/3, 1]

# Plot the points and the piecewise linear curve
plt.plot(x, y, '-o', label='Piecewise Linear Curve')
plt.scatter(x, y, color='red')  # This will mark the specific points in red

# Annotate the points
for i, txt in enumerate(zip(x, y)):
    plt.annotate(f"({txt[0]:.2f}, {txt[1]:.2f})", (x[i], y[i]), xytext=(5,-10), textcoords='offset points')

# Set labels and title
plt.xlabel('$p_T$')
plt.ylabel('$V(1,B,p_T)$')
plt.grid(True)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt

# Define the first set of points
x1 = [0, 2/3, 1]
y1 = [-2, 2/3, 1]

# Define the second set of points
x2 = [0, 3/4, 1]
y2 = [-1, 1/2, 0]

# max V
x3 = [0, 0.5, 2/3, 1]
y3 = [-1, 0, 2/3, 1]

# cav max V
x4 = [0, 2/3, 1]
y4 = [-1, 2/3, 1]

# Plot the second set of points and its piecewise linear curve
plt.plot(x4, y4, '-o', label='$Cav_p(\max_u V(1,u,p))$', color='black', linewidth=6.)
plt.scatter(x4, y4, color='orange')  # This will mark the specific points in orange

# Plot the second set of points and its piecewise linear curve
plt.plot(x3, y3, '-o', label='$\max_u V(1,u,p)$', color='orange', linewidth=4.)
plt.scatter(x3, y3, color='orange')  # This will mark the specific points in orange

# Plot the first set of points and its piecewise linear curve
plt.plot(x1, y1, '-o', label='$V(1,B,p)$', color='blue')
plt.scatter(x1, y1, color='red')  # This will mark the specific points in red

# Plot the second set of points and its piecewise linear curve
plt.plot(x2, y2, '-o', label='$V(1,Q,p)$', color='green')
plt.scatter(x2, y2, color='orange')  # This will mark the specific points in orange

# Annotate the points for the first curve
for i, txt in enumerate(zip(x1, y1)):
    plt.annotate(f"({txt[0]:.2f}, {txt[1]:.2f})", (x1[i], y1[i]), xytext=(5,-10), textcoords='offset points', fontsize=9)

# Annotate the points for the second curve
for i, txt in enumerate(zip(x2, y2)):
    plt.annotate(f"({txt[0]:.2f}, {txt[1]:.2f})", (x2[i], y2[i]), xytext=(5,-10), textcoords='offset points', fontsize=9)

# Set labels, title, and other plot properties
plt.xlabel('$p_T$',fontsize=20)
plt.ylabel('$Value$',fontsize=20)
plt.title('Primal Value for the Zero-sum Beer-quiche Game',fontsize=18)
plt.grid(True)
plt.legend()
plt.axis([-0.1, 1.1, -2.1, 1.1])  # This sets the axis limits for a clearer view
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Define a meshgrid for x and y values
x = np.linspace(-10, 10, 400)
y = np.linspace(-10, 10, 400)
X, Y = np.meshgrid(x, y)

# Calculate Z values for each plane
Z1 = X - 1
Z2 = X - 2
Z3 = Y + 2
Z4 = Y

fig = plt.figure(figsize=(10, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot each plane
ax.plot_surface(X, Y, Z1, alpha=0.5, rstride=100, cstride=100, color='blue', label='f(x,y) = x - 1')
ax.plot_surface(X, Y, Z2, alpha=0.5, color='red', rstride=100, cstride=100, label='f(x,y) = x - 2')
ax.plot_surface(X, Y, Z3, alpha=0.5, color='green', rstride=100, cstride=100, label='f(x,y) = y + 2')
ax.plot_surface(X, Y, Z4, alpha=0.5, color='purple', rstride=100, cstride=100, label='f(x,y) = y')

# Set labels and title
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
ax.set_title('Planes in 3D Space')
ax.view_init(elev=20, azim=-60)  # Set a good viewing angle

# Due to a limitation in mplot3d, the legend cannot be directly created for surfaces. 
# Therefore, we use proxy artists for the legend.
blue_proxy = plt.Rectangle((0, 0), 1, 1, fc="blue", alpha=0.5)
red_proxy = plt.Rectangle((0, 0), 1, 1, fc="red", alpha=0.5)
green_proxy = plt.Rectangle((0, 0), 1, 1, fc="green", alpha=0.5)
purple_proxy = plt.Rectangle((0, 0), 1, 1, fc="purple", alpha=0.5)
ax.legend([blue_proxy, red_proxy, green_proxy, purple_proxy], ['f(x,y) = x - 1', 'f(x,y) = x - 2', 'f(x,y) = y + 2', 'f(x,y) = y'])

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# Define a meshgrid for x and y values
x = np.linspace(-10, 10, 400)
y = np.linspace(-10, 10, 400)
X, Y = np.meshgrid(x, y)

# Initialize a Z matrix with zeros
Z = np.zeros_like(X)

# Determine the values of Z based on the piecewise conditions
Z[Y > X - 1] = X[Y > X - 1] - 1
Z[(Y <= X - 1) & (Y > X - 2)] = Y[(Y <= X - 1) & (Y > X - 2)]
Z[(Y <= X - 2) & (Y > X - 4)] = X[(Y <= X - 2) & (Y > X - 4)] - 2
Z[Y <= X - 4] = Y[Y <= X - 4] + 2

# Create the contour plot
plt.contourf(X, Y, Z, 20, cmap='viridis')
plt.colorbar(label='conjugate value')
plt.contour(X, Y, Z, 20, colors='black', linewidths=0.5)
plt.plot(x, x-1, 'r--', label="$\hat{p}_2=\hat{p}_1-1$")
plt.plot(x, x-2, 'b--', label="$\hat{p}_2=\hat{p}_1-2$")
plt.plot(x, x-4, 'g--', label="$\hat{p}_2=\hat{p}_1-4$")

# Set labels, title, and other properties
plt.xlabel('$\hat{p}_1$',fontsize=20)
plt.ylabel('$\hat{p}_2$',fontsize=20)
plt.title('$\max_v ~C(t=2,(B,v),\hat{p})$',fontsize=18)
plt.legend()
# plt.grid(True)
plt.axis([-10, 10, -10, 10])
plt.show()

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=59115d46-a419-43f9-a3fe-b160aca2a335' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
